# %% [markdown]
# <a href="https://colab.research.google.com/github/jeyanthi492/ML-projects/blob/main/Stock%20price%20prediction/Stock%20price%20prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Stock prediction using support vector regression

# %%
# Kaggle
"""
project dataset
image dataset
text dataset
code
data visualization - projects
competition

conversations

Github:
framework also used - may be difficult to understand - advanced codes

Instagram:
Algorithm ->share,like,timing -> suggestion -> trend

google colab
 - files can be added
  - download as .py


Alt+3 = comment
Alt+4 = uncomment
"""
# Out:
# '\nproject dataset\nimage dataset\ntext dataset\ncode\ndata visualization - projects\ncompetition\n\nconversations\n\nGithub:\nframework also used - may be difficult to understand - advanced codes\n\nInstagram:\nAlgorithm ->share,like,timing -> suggestion -> trend\n\ngoogle colab\n - files can be added\n  - download as .py\n\n\nAlt+3 = comment\nAlt+4 = uncomment\n'

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-f6c2ec50-6196-4711-8b03-e005c518fd3e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f6c2ec50-6196-4711-8b03-e005c518fd3e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
dataset = pd.read_excel('Stockmarket - Retrieved data.xlsx')
print(dataset.shape)
print(dataset.head(5))
dataset
# Out:
# (499, 5)
#         date       open       high        low      close
# 0 2022-01-03  17.799999  18.219000  17.500000  17.760000
# 1 2022-01-04  17.700001  18.309999  17.620001  17.660000
# 2 2022-01-05  17.580000  17.799999  16.910000  16.950001
# 3 2022-01-06  16.650000  16.879999  16.139999  16.170000
# 4 2022-01-07  16.219999  16.290001  15.630000  15.710000
#           date       open       high        low      close
# 0   2022-01-03  17.799999  18.219000  17.500000  17.760000
# 1   2022-01-04  17.700001  18.309999  17.620001  17.660000
# 2   2022-01-05  17.580000  17.799999  16.910000  16.950001
# 3   2022-01-06  16.650000  16.879999  16.139999  16.170000
# 4   2022-01-07  16.219999  16.290001  15.630000  15.710000
# ..         ...        ...        ...        ...        ...
# 494 2022-12-20   2.070000   2.240000   2.070000   2.100000
# 495 2022-12-21   2.050000   2.200000   2.050000   2.055000
# 496 2022-12-22   2.125000   2.180000   1.960000   1.960000
# ...

# %%
X = dataset.iloc[:, 1:-1].values
print(X)
print('Jey')
Y = dataset.iloc[:, -1].values
print(Y)
# Out:
# [[17.79999924 18.21899986 17.5       ]
#  [17.70000076 18.30999947 17.62000084]
#  [17.57999992 17.79999924 16.90999985]
#  ...
#  [ 2.125       2.18000007  1.96000004]
#  [ 1.95500004  2.0999999   1.89999998]
#  [ 1.92499995  2.04999995  1.90499997]]
# Jey
# [17.76000023 17.65999985 16.95000076 16.17000008 15.71000004 15.85999966
#  16.28000069 16.02000046 15.81000042 15.59000015 15.39999962 14.97999954
#  14.90999985 14.40999985 14.40999985 14.22999954 14.18000031 13.64999962
#  13.22999954 14.22999954 14.38000011 14.06000042 13.48999977 13.57999992
#  14.05000019 14.73999977 14.97999954 15.27000046 15.06000042 14.81999969
#  15.5        15.77000046 15.11999989 15.21000004 15.68000031 15.36999989
#  15.51000023 15.82999992 15.65999985 15.55000019 16.25       15.65999985
#  15.52000046 15.64999962 15.52999973 15.60999966 15.44999981 14.85000038
#  14.35000038 15.22000027 15.55000019 16.02000046 16.47999954 16.38999939
# ...

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.25, random_state=0)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (374, 3)
# (125, 3)
# (374,)
# (125,)

# %%
from sklearn.svm import SVR
model = SVR(kernel='rbf')    # model performance will be changed based on the parameters
model.fit(x_train, y_train)
# Out:
# SVR()

# %%
"""
SSres is the sum of squares of the residual errors.
SStot is the total sum of the errors.
R^2 = 1 - (SSres/SStot)                 R^2 score should be high for the good model
"""

y_pred = model.predict(x_test)

from sklearn.metrics import r2_score, mean_squared_error
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
print("Root Mean Square Error:", rmse)
r2score = r2_score(y_test, y_pred)
print("R2Score", r2score*100)
# Out:
# Root Mean Square Error: 0.27219965311716643
# R2Score 99.84892629279237

# %%
from matplotlib import pyplot as plt
plt.scatter(x_train[:,1], y_train, color='red')
plt.scatter(x_test[:,1], y_pred, color='black')

# %%
ypred = model.predict([[16.64999962,	16.87999916,	16.13999939]])
ypred
#16.17000008 - original
# Out:
# array([16.55502628])
